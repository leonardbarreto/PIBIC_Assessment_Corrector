# %% [markdown]
# Carregar conjunto de documentos do diretório
# ====

# %%
import os
from itertools import islice

path="/home/leonard/Faculdades/ESTACIO/Projetos/IC/2017-2018/Luiz/Dados/SistMicroprocessadores"
def encontraArquivosEmPastaRecursivamente(pasta, extensao):
    arquivosTxt = []
    caminhoAbsoluto = os.path.abspath(pasta)
    for pastaAtual, subPastas, arquivos  in os.walk(caminhoAbsoluto):
        arquivosTxt.extend([os.path.join(pastaAtual,arquivo) for arquivo in arquivos if arquivo.endswith('.txt')])
    return arquivosTxt


arquivos = encontraArquivosEmPastaRecursivamente(path, '.txt')

'''
Padrão do arquivo
1a linha: <nota atribuída> de <valor da questão>
2a linha: em branco
3a linha em diante: resposta
'''
corpus_respostas=[]
for a in arquivos:
    arq = open(a,'r')
    with open(a) as lines:
        #lines = arq.readlines()
        lines = [lines.rstrip("\n") for lines in arq] #retirar o caracter de fim de linha
        # then skip the next 2
        for line in islice(lines, 3):
            pass
        corpus_respostas.append(line)
    arq.close()

print(len(corpus_respostas))
#print(corpus_respostas)
# Out:
# 15

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
#O gabarito está na posição 0
gabarito = "O desvio no programa ocorre sempre que o programa sai da sequência normal de execução. Existem basicamente dois tipos de desvio: desvio incondicional e desvio condicional. O desvio incondicional ocorre quando o programa sai da sequência normal de execução e é desviado para outro ponto da memória de programa independente de qualquer condição; o desvio ocorre sem depender de nada. Um exemplo de um desvio incondicional é aquele provocado pela instrução GOTO. No desvio condicional, uma condição deve ser satisfeita para que o desvio ocorra. Normalmente uma determinada condição é testada e, se o teste for validado, ocorre o desvio."
respostas = corpus_respostas
respostas.insert(0,gabarito)
#respostas[0]

# %% [markdown]
# Pré-processamento
# =====
# 1. remoção de stopwords
# 2. remoção de pontuações

# %%
#Retirar pontuação
from string import punctuation
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

#print(strip_punctuation(respostas[0]))

# %%
#Retirar stopwords
def remove_stopwords(text):
    return ' '.join([w.lower() for w in text.split() if w not in stopwords])

# %%
#Retirar caracteres especiais
import unicodedata
import re
def remove_special_chars(text):
    nfkd = unicodedata.normalize('NFKD', text)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])
    return re.sub(u'[^a-zA-Z0-9áéíóúÁÉÍÓÚâêîôÂÊÎÔãõÃÕçÇ: ]', '', palavraSemAcento)

# %%
import gensim
from nltk import ngrams 
from nltk.tokenize import word_tokenize

#gabarito = 'O desvio no programa ocorre sempre que o programa sai da sequência normal de execução. Existem basicamente dois tipos de desvio: desvio incondicional e desvio condicional. O desvio incondicional ocorre quando o programa sai da sequência normal de execução e é desviado para outro ponto da memória de programa independente de qualquer condição; o desvio ocorre sem depender de nada. Um exemplo de um desvio incondicional é aquele provocado pela instrução GOTO. No desvio condicional, uma condição deve ser satisfeita para que o desvio ocorra. Normalmente uma determinada condição é testada e, se o teste for validado, ocorre o desvio.'

def word_grams(words, min=1, max=3):
    s = []
    if isinstance(words,str): 
        words=words.split()
    
    for n in range(min, max+1):
        for ngram in ngrams(words, n):
            s.append(' '.join(str(i) for i in ngram))
    return s

'''
def merge_two_dicts(x, y):
    """Given two dicts, merge them into a new dict as a shallow copy."""
    z = x.copy()
    z.update(y)
    return z

def ngrams_split(lst, n):
    counts = dict()
    grams = [' '.join(lst[i:i+n]) for i in range(len(lst)-n)]
    for gram in grams:
        if gram not in counts:
            counts[gram] = 1
        else:
            counts[gram] += 1
    return counts

gabarito_2grams = ngrams_split(gabarito.split(),2)
gabarito_3grams = ngrams_split(gabarito.split(),3)
ngram=merge_two_dicts(gabarito_3grams,gabarito_2grams)
ngram=merge_two_dicts(ngram,ngrams_split(gabarito.split(),1))
'''
# Out:
# '\ndef merge_two_dicts(x, y):\n    """Given two dicts, merge them into a new dict as a shallow copy."""\n    z = x.copy()\n    z.update(y)\n    return z\n\ndef ngrams_split(lst, n):\n    counts = dict()\n    grams = [\' \'.join(lst[i:i+n]) for i in range(len(lst)-n)]\n    for gram in grams:\n        if gram not in counts:\n            counts[gram] = 1\n        else:\n            counts[gram] += 1\n    return counts\n\ngabarito_2grams = ngrams_split(gabarito.split(),2)\ngabarito_3grams = ngrams_split(gabarito.split(),3)\nngram=merge_two_dicts(gabarito_3grams,gabarito_2grams)\nngram=merge_two_dicts(ngram,ngrams_split(gabarito.split(),1))\n'

# %%
"""
from tabulate import tabulate
import pandas as pd
def printf(lst):
    df = pd.DataFrame(list(lst))
    print(tabulate(df,headers='keys', tablefmt='psql'))
"""
# Out:
# "\nfrom tabulate import tabulate\nimport pandas as pd\ndef printf(lst):\n    df = pd.DataFrame(list(lst))\n    print(tabulate(df,headers='keys', tablefmt='psql'))\n"

# %%
def pre_processamento(lst):
    item=[]
    for idx,val in enumerate(lst):
        val=val.lower()
        s=strip_punctuation(val)
        s=remove_stopwords(val)
        s=remove_special_chars(val)

        item.append(s)
    return item

# %% [markdown]
# Bag of words pacote sklearn
# ====

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# PRÉ-PROCESSAMENTO
respostas = pre_processamento(respostas)
#print(respostas)

######################

vectorizer = CountVectorizer(analyzer = "word", tokenizer = word_grams, preprocessor = None, stop_words = stopwords, max_features = 5000) 

train_data_features = vectorizer.fit_transform(respostas)
train_data_features = train_data_features.toarray()


vocab = vectorizer.get_feature_names()
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

print(len(vocab))
# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 891
# 1 3
# 1 3 tipos
# 1 3 tipos de
# 1 a execucao
# 1 a execucao e
# 1 a falha
# 1 a falha em
# 1 a goto
# 1 a goto que
# 3 a instrucao
# 2 a instrucao de
# 1 a instrucao que
# 1 a linha
# 1 a linha determinada
# 1 a necessidade
# 1 a operar
# 1 a operar a
# 2 a partir
# 2 a partir de
# 1 a serem
# 1 a serem atendidas
# 1 acontece
# 1 acontece quando
# 1 acontece quando ha
# 1 acordo
# 1 acordo com
# 1 acordo com a
# 1 alguma
# 1 alguma condicao
# 1 alguma condicao esvio
# 1 algumas
# 1 algumas condicoes
# 1 algumas condicoes a
# 1 alterado
# 1 alterado para
# 1 alterado para o
# 1 anteriormente
# 1 anteriormente a
# 1 anteriormente a instrucao
# 1 antes
# 1 antes dele
# 1 antes dele ter
# 1 apontada
# 1 apontada pelo
# 1 apontada pelo pc
# 1 apos
# 1 apos o
# 1 apos o tratamento
# 1 aquele provocado
# 1 aquele provocado pela
# 1 assim
# 1 assim apos
# 1 assim apos o
# 1 atendidas
# 1 atendidas a
# 1 atendidas a partir
# 1 atualizar
# 1 atualizar o
# 1 atualizar o registrador
# 1 basica
# 1 basica e
# 1 basica e a
# 3 basicamente
# 3 basicamente dois
# 3 basicamente dois tipos
# 1 buscada
# 1 buscada pelo
# 1 buscada pelo sistema
# 1 caso
# 1 caso ocorrera
# 1 caso ocorrera o
# 1 certas
# 1 certas condicoes
# 1 certas condicoes para
# 1 ciclo
# 1 ciclo de
# 1 ciclo de maquina
# 1 com a
# 1 com a necessidade
# 11 condicao
# 1 condicao desvio
# 1 condicao desvio condicional:
# 3 condicao deve
# 3 condicao deve ser
# 2 condicao e
# 2 condicao e testada
# 1 condicao esvio
# 1 condicao esvio prevista
# 3 condicao o
# 3 condicao o desvio
# 1 condicao ou
# 1 condicao ou sozinho
# 9 condicional
# 1 condicional depende
# 1 condicional depende de
# 1 condicional desvio
# 1 condicional desvio incondicional:
# 2 condicional e
# 1 condicional e incondicional
# 1 condicional e necessario
# 2 condicional o
# 2 condicional o desvio
# 2 condicional uma
# 2 condicional uma condicao
# 2 condicional:
# 2 condicional: uma
# 1 condicional: uma condicao
# 1 condicional: uma funcao
# 2 condicoes
# 1 condicoes a
# 1 condicoes a serem
# 1 condicoes para
# 1 condicoes para que
# 3 controlador
# 2 controlador digital
# 2 controlador digital de
# 1 controlador do
# 1 controlador do programa
# 1 counter
# 1 counter ou
# 1 counter ou no
# 1 da execucao
# 1 da execucao e
# 1 da frequencia
# 1 da frequencia nominal
# 7 da memoria
# 2 da memoria de
# 2 da memoria do
# 1 da memoria independente
# 1 da memoria no
# 1 da memoria sem
# 1 da problema
# 1 da problema no
# 10 da sequencia
# 1 da sequencia do
# 1 da sequencia nominal
# 8 da sequencia normal
# 1 da sequencial
# 1 da sequencial normal
# 3 da sua
# 3 da sua sequencia
# 1 de acordo
# 1 de acordo com
# 1 de algumas
# 1 de algumas condicoes
# 3 de desvio
# 1 de desvio a
# 1 de desvio basica
# 1 de desvio desvio
# 3 de desvio:
# 3 de desvio: desvio
# 1 de desvios:
# 1 de desvios: desvios
# 11 de execucao
# 5 de execucao e
# 1 de execucao existe
# 5 de execucao existem
# 1 de forma
# 1 de forma imediata
# 1 de funcionamento
# 1 de maquina
# 1 de maquina dsc
# 2 de memoria
# 1 de memoria de
# 1 de memoria eeprom
# 3 de nada
# 1 de nada desvio
# 1 de nada um
# 1 de onde
# 1 de onde ocorreu
# 1 de pipeline
# 1 de pipeline nao
# 4 de programa
# 1 de programa apontada
# 1 de programa independente
# 1 de programa o
# 1 de programa ocorre
# 5 de qualquer
# 4 de qualquer condicao
# 1 de qualquer fator
# 1 de sequencia
# 1 de sequencia normal
# 3 de sinais
# 1 de sinais dsp
# 1 de testes
# 1 de testes esses
# 1 de um
# 1 de um desvio
# 1 dele ter
# 1 dele ter seu
# 1 demanda
# 1 demanda um
# 1 demanda um ciclo
# 1 depende
# 1 depende de
# 1 depende de algumas
# 3 depender
# 3 depender de
# 3 depender de nada
# 1 destino
# 1 destino especificado
# 1 destino especificado toda
# 1 desviada
# 1 desviada para
# 1 desviada para o
# 6 desviado
# 6 desviado para
# 6 desviado para outro
# 42 desvio
# 2 desvio a
# 2 desvio a instrucao
# 1 desvio acontece
# 1 desvio acontece quando
# 1 desvio basica
# 1 desvio basica e
# 6 desvio condicional
# 2 desvio condicional e
# 1 desvio condicional o
# 2 desvio condicional uma
# 2 desvio condicional:
# 2 desvio condicional: uma
# 1 desvio de
# 1 desvio de programa
# 1 desvio desvio
# 1 desvio desvio incondicional
# 1 desvio em
# 1 desvio em um
# 9 desvio incondicional
# 4 desvio incondicional e
# 4 desvio incondicional ocorre
# 1 desvio incondicional que
# 2 desvio incondicional:
# 2 desvio incondicional: ocorre
# 4 desvio no
# 4 desvio no programa
# 2 desvio ocorra
# 2 desvio ocorra normalmente
# 5 desvio ocorre
# 3 desvio ocorre sem
# 1 desvio ocorre sempre
# 1 desvio ocorrer
# 1 desvio seja
# 1 desvio seja feito
# 3 desvio:
# 3 desvio: desvio
# 3 desvio: desvio incondicional
# 3 desvios
# 1 desvios condicional
# 1 desvios condicional o
# 1 desvios incondicional
# 1 desvios incondicional e
# 1 desvios ocorrem
# 1 desvios ocorrem quando
# 1 desvios:
# 1 desvios: desvios
# 1 desvios: desvios incondicional
# 3 determinada
# 2 determinada condicao
# 2 determinada condicao e
# 1 determinada nesta
# 1 determinada nesta instrucao
# 4 deve
# 1 deve se
# 1 deve se satisfeita
# 3 deve ser
# 3 deve ser satisfeita
# 3 digital
# 3 digital de
# 3 digital de sinais
# 1 do evento
# 1 do evento o
# 1 do normal
# 1 do normal existem
# 1 do operador
# 1 do operador intervir
# 1 do pic
# 1 do pic demanda
# 3 do programa
# 2 do programa independente
# 1 do programa para
# 5 dois
# 5 dois tipos
# 5 dois tipos de
# 2 dsc
# 2 dsc controlador
# 2 dsc controlador digital
# 1 dsp
# 1 dsp processamento
# 1 dsp processamento digital
# 2 e a
# 1 e a execucao
# 1 e a goto
# 1 e aquele
# 1 e aquele provocado
# 1 e condicional
# 1 e condicional desvio
# 1 e desviada
# 1 e desviada para
# 6 e desviado
# 6 e desviado para
# 2 e desvio
# 2 e desvio condicional
# 1 e desvios
# 1 e desvios condicional
# 5 e e
# 5 e e desviado
# 1 e enviado
# 1 e enviado para
# 1 e erromopt
# 1 e incondicional
# 1 e incondicional desvio
# 1 e necessario
# 1 e necessario certas
# 2 e se
# 2 e se o
# 2 e testada
# 2 e testada e
# 1 e valida
# 1 e valida pois
# 1 eeprom
# 1 eeprom flash
# 1 eeprom flash e
# 1 em atualizar
# 1 em atualizar o
# 1 em determinada
# 1 em determinada condicao
# 1 em um
# 1 em um programa
# 1 endereco
# 1 endereco predefinido
# 1 endereco predefinido onde
# 1 enviado
# 1 enviado para
# 1 enviado para um
# 1 erromopt
# 1 especificado
# 1 especificado toda
# 1 especificado toda instrucao
# 1 esse evento
# 1 esse evento externo
# 1 esse temporizador
# 1 esse temporizador reinicializa
# 1 esses desvios
# 1 esses desvios ocorrem
# 1 estava na
# 1 estava na posicao
# 1 esvio
# 1 esvio prevista
# 1 esvio prevista ocorre
# 2 evento
# 1 evento externo
# 1 evento externo e
# 1 evento o
# 1 evento o sistema
# 13 execucao
# 7 execucao e
# 1 execucao e desviada
# 1 execucao e desviado
# 5 execucao e e
# 1 execucao existe
# 1 execucao existe o
# 5 execucao existem
# 1 execucao existem 3
# 3 execucao existem basicamente
# 1 execucao existem dois
# 1 exemplo
# 1 exemplo de
# 1 exemplo de um
# 1 existe
# 1 existe o
# 1 existe o desvio
# 6 existem
# 1 existem 3
# 1 existem 3 tipos
# 3 existem basicamente
# 3 existem basicamente dois
# 2 existem dois
# 2 existem dois tipos
# 1 externo
# 1 externo e
# 1 externo e enviado
# 1 falha
# 1 falha em
# 1 falha em atualizar
# 1 fator
# 1 fator nesse
# 1 fator nesse caso
# 1 feito
# 1 flash
# 1 flash e
# 1 flash e erromopt
# 1 foi previamente
# 1 foi previamente buscada
# 2 for validado
# 2 for validado ocorre
# 1 forma
# 1 forma imediata
# 1 forma imediata de
# 1 frequencia
# 1 frequencia nominal
# 1 frequencia nominal de
# 1 funcao
# 1 funcao deve
# 1 funcao deve se
# 1 funcionamento
# 3 goto
# 1 goto condicional
# 1 goto condicional depende
# 1 goto no
# 1 goto no desvio
# 1 goto que
# 1 goto que leva
# 1 ha
# 1 ha necessidade
# 1 ha necessidade do
# 1 imediata
# 1 imediata de
# 1 imediata de acordo
# 12 incondicional
# 1 incondicional desvio
# 1 incondicional desvio incondicional
# 5 incondicional e
# 1 incondicional e aquele
# 1 incondicional e condicional
# 2 incondicional e desvio
# 1 incondicional e desvios
# 5 incondicional ocorre
# 1 incondicional ocorre independente
# 3 incondicional ocorre quando
# 1 incondicional ocorre quano
# 1 incondicional que
# 1 incondicional que ocorre
# 2 incondicional:
# 2 incondicional: ocorre
# 1 incondicional: ocorre quando
# 1 incondicional: ocorre quano
# 5 independente
# 5 independente de
# 5 independente de qualquer
# 6 instrucao
# 2 instrucao de
# 2 instrucao de desvio
# 1 instrucao do
# 1 instrucao do pic
# 1 instrucao goto
# 1 instrucao goto no
# 1 instrucao que
# 1 instrucao que ja
# 1 intervir
# 1 intervir no
# 1 intervir no programa
# 1 ja
# 1 ja foi
# 1 ja foi previamente
# 1 leva
# 1 leva o
# 1 leva o programa
# 1 linha
# 1 linha determinada
# 1 linha determinada nesta
# 1 logo
# 1 logo esse
# 1 logo esse evento
# 1 maquina
# 1 maquina dsc
# 1 maquina dsc controlador
# 9 memoria
# 3 memoria de
# 3 memoria de programa
# 2 memoria do
# 2 memoria do programa
# 1 memoria eeprom
# 1 memoria eeprom flash
# 1 memoria independente
# 1 memoria independente de
# 1 memoria no
# 1 memoria no desvio
# 1 memoria sem
# 1 memoria sem ser
# 1 mesmo sera
# 1 mesmo sera tratado
# 1 microcontrolador
# 1 microcontrolador sistema
# 1 microcontrolador sistema operacional
# 1 microcontroladores
# 1 na posicao
# 1 na posicao de
# 3 nada
# 1 nada desvio
# 1 nada desvio condicional:
# 1 nada um
# 1 nada um exemplo
# 1 nao
# 1 nao e
# 1 nao e valida
# 1 necessario
# 1 necessario certas
# 1 necessario certas condicoes
# 2 necessidade
# 1 necessidade do
# 1 necessidade do operador
# 1 nesse
# 1 nesse caso
# 1 nesse caso ocorrera
# 1 nesta
# 1 nesta instrucao
# 1 no controlador
# 1 no controlador do
# 2 no desvio
# 2 no desvio condicional
# 5 no programa
# 4 no programa ocorre
# 1 no programa pode
# 1 no registrador
# 1 no registrador program
# 2 nominal
# 1 nominal da
# 1 nominal da execucao
# 1 nominal de
# 1 nominal de execucao
# 12 normal
# 10 normal de
# 10 normal de execucao
# 1 normal e
# 1 normal e a
# 1 normal existem
# 1 normal existem dois
# 2 normalmente
# 1 normalmente em
# 1 normalmente em determinada
# 1 normalmente uma
# 1 normalmente uma determinada
# 1 o destino
# 1 o destino especificado
# 21 o desvio
# 1 o desvio condicional
# 1 o desvio de
# 3 o desvio incondicional
# 4 o desvio no
# 2 o desvio ocorra
# 5 o desvio ocorre
# 1 o desvio ocorrer
# 1 o desvio seja
# 1 o goto
# 1 o goto condicional
# 1 o mesmo
# 1 o mesmo sera
# 1 o microcontrolador
# 1 o microcontrolador sistema
# 1 o outro
# 1 o outro ponto
# 1 o program
# 1 o program sai
# 15 o programa
# 1 o programa para
# 14 o programa sai
# 1 o registrador
# 1 o registrador logo
# 1 o sistema
# 1 o sistema volta
# 2 o teste
# 2 o teste for
# 1 o tratamento
# 1 o tratamento do
# 2 ocorra
# 2 ocorra normalmente
# 1 ocorra normalmente em
# 1 ocorra normalmente uma
# 26 ocorre
# 1 ocorre a
# 1 ocorre a falha
# 1 ocorre anteriormente
# 1 ocorre anteriormente a
# 1 ocorre independente
# 1 ocorre independente de
# 2 ocorre o
# 2 ocorre o desvio
# 7 ocorre quando
# 1 ocorre quando alguma
# 5 ocorre quando o
# 1 ocorre quando um
# 3 ocorre quano
# 3 ocorre quano o
# 3 ocorre sem
# 3 ocorre sem depender
# 6 ocorre sempre
# 6 ocorre sempre que
# 1 ocorre um
# 1 ocorre um desvio
# 1 ocorrem
# 1 ocorrem quando
# 1 ocorrem quando o
# 1 ocorrer
# 1 ocorrera
# 1 ocorrera o
# 1 ocorrera o goto
# 1 ocorreu
# 1 ocorreu o
# 1 ocorreu o desvio
# 2 onde
# 1 onde o
# 1 onde o mesmo
# 1 onde ocorreu
# 1 onde ocorreu o
# 1 operacional
# 1 operacional quando
# 1 operacional quando ocorre
# 1 operador
# 1 operador intervir
# 1 operador intervir no
# 1 operar
# 1 operar a
# 1 operar a partir
# 1 ou de
# 1 ou de forma
# 1 ou no
# 1 ou no controlador
# 1 ou sozinho
# 1 ou sozinho desvio
# 7 outro
# 7 outro ponto
# 7 outro ponto da
# 1 para a
# 1 para a linha
# 1 para microcontroladores
# 3 para o
# 1 para o destino
# 1 para o desvio
# 1 para o outro
# 6 para outro
# 6 para outro ponto
# 4 para que
# 4 para que o
# 1 para um
# 1 para um endereco
# 2 partir
# 2 partir de
# 1 partir de onde
# 1 partir de testes
# 1 pc
# 1 pc antes
# 1 pc antes dele
# 1 pela instrucao
# 1 pela instrucao goto
# 1 pelo pc
# 1 pelo pc antes
# 1 pelo sistema
# 1 pelo sistema de
# 1 pic
# 1 pic demanda
# 1 pic demanda um
# 1 pipeline
# 1 pipeline nao
# 1 pipeline nao e
# 1 pode
# 1 pode ser
# 1 pode ser programavel
# 1 pois
# 1 pois estava
# 1 pois estava na
# 7 ponto
# 7 ponto da
# 7 ponto da memoria
# 1 por uma
# 1 por uma condicao
# 1 posicao
# 1 posicao de
# 1 posicao de memoria
# 1 predefinido
# 1 predefinido onde
# 1 predefinido onde o
# 1 previamente
# 1 previamente buscada
# 1 previamente buscada pelo
# 1 prevista
# 1 prevista ocorre
# 1 prevista ocorre anteriormente
# 1 problema
# 1 problema no
# 1 problema no registrador
# 1 processamento
# 1 processamento digital
# 1 processamento digital de
# 2 program
# 1 program counter
# 1 program counter ou
# 1 program sai
# 1 program sai da
# 29 programa
# 1 programa apontada
# 1 programa apontada pelo
# 3 programa independente
# 3 programa independente de
# 1 programa o
# 1 programa o desvio
# 6 programa ocorre
# 1 programa ocorre quando
# 5 programa ocorre sempre
# 2 programa para
# 1 programa para a
# 1 programa para microcontroladores
# 1 programa pode
# 1 programa pode ser
# 15 programa sai
# 14 programa sai da
# 1 programa sai de
# 1 programavel
# 1 programavel ou
# 1 programavel ou de
# 1 provocado
# 1 provocado pela
# 1 provocado pela instrucao
# 5 qualquer
# 4 qualquer condicao
# 1 qualquer condicao desvio
# 3 qualquer condicao o
# 1 qualquer fator
# 1 qualquer fator nesse
# 1 quando alguma
# 1 quando alguma condicao
# 1 quando da
# 1 quando da problema
# 1 quando ha
# 1 quando ha necessidade
# 6 quando o
# 6 quando o programa
# 2 quando ocorre
# 1 quando ocorre a
# 1 quando ocorre um
# 1 quando um
# 1 quando um programa
# 3 quano
# 3 quano o
# 1 quano o program
# 2 quano o programa
# 1 que ja
# 1 que ja foi
# 1 que leva
# 1 que leva o
# 10 que o
# 4 que o desvio
# 6 que o programa
# 1 que ocorre
# 1 que ocorre quano
# 2 registrador
# 1 registrador logo
# 1 registrador logo esse
# 1 registrador program
# 1 registrador program counter
# 1 reinicializa
# 1 reinicializa o
# 1 reinicializa o microcontrolador
# 16 sai
# 15 sai da
# 1 sai da frequencia
# 10 sai da sequencia
# 1 sai da sequencial
# 3 sai da sua
# 1 sai de
# 1 sai de sequencia
# 4 satisfeita
# 4 satisfeita para
# 1 satisfeita para o
# 3 satisfeita para que
# 2 se o
# 2 se o teste
# 1 se satisfeita
# 1 se satisfeita para
# 1 seja feito
# 3 sem depender
# 3 sem depender de
# 1 sem ser
# 1 sem ser solicitado
# 6 sempre
# 6 sempre que
# 6 sempre que o
# 14 sequencia
# 1 sequencia de
# 1 sequencia de funcionamento
# 1 sequencia do
# 1 sequencia do normal
# 1 sequencia nominal
# 1 sequencia nominal da
# 10 sequencia normal
# 9 sequencia normal de
# 1 sequencia normal e
# 1 sequencia por
# 1 sequencia por uma
# 1 sequencial
# 1 sequencial normal
# 1 sequencial normal de
# 5 ser
# 1 ser programavel
# 1 ser programavel ou
# 3 ser satisfeita
# 3 ser satisfeita para
# 1 ser solicitado
# 1 sera
# 1 sera tratado
# 1 sera tratado assim
# 1 serem
# 1 serem atendidas
# 1 serem atendidas a
# 1 seu valor
# 1 seu valor alterado
# 3 sinais
# 1 sinais dsp
# 1 sinais dsp processamento
# 3 sistema
# 1 sistema de
# 1 sistema de pipeline
# 1 sistema operacional
# 1 sistema operacional quando
# 1 sistema volta
# 1 sistema volta a
# 1 solicitado
# 1 sozinho
# 1 sozinho desvio
# 1 sozinho desvio incondicional:
# 3 sua sequencia
# 1 sua sequencia de
# 1 sua sequencia normal
# 1 sua sequencia por
# 1 temporizador
# 1 temporizador reinicializa
# 1 temporizador reinicializa o
# 1 ter
# 1 ter seu
# 1 ter seu valor
# 2 testada
# 2 testada e
# 2 testada e se
# 2 teste
# 2 teste for
# 2 teste for validado
# 1 testes
# 1 testes esses
# 1 testes esses desvios
# 1 timer:
# 1 timer: esse
# 1 timer: esse temporizador
# 6 tipos
# 6 tipos de
# 1 tipos de desvio
# 3 tipos de desvio:
# 1 tipos de desvios:
# 1 tipos de memoria
# 1 toda
# 1 toda instrucao
# 1 toda instrucao do
# 1 tratado
# 1 tratado assim
# 1 tratado assim apos
# 1 tratamento
# 1 tratamento do
# 1 tratamento do evento
# 1 um ciclo
# 1 um ciclo de
# 3 um desvio
# 1 um desvio a
# 1 um desvio em
# 1 um desvio incondicional
# 1 um endereco
# 1 um endereco predefinido
# 1 um exemplo
# 1 um exemplo de
# 2 um programa
# 1 um programa ocorre
# 1 um programa sai
# 4 uma condicao
# 3 uma condicao deve
# 1 uma condicao ou
# 1 uma determinada
# 1 uma determinada condicao
# 1 uma funcao
# 1 uma funcao deve
# 1 valida
# 1 valida pois
# 1 valida pois estava
# 2 validado
# 2 validado ocorre
# 2 validado ocorre o
# 1 valor
# 1 valor alterado
# 1 valor alterado para
# 1 volta
# 1 volta a
# 1 volta a operar
# 1 watchdog
# 1 watchdog timer:
# 1 watchdog timer: esse

# %% [markdown]
# Avaliar a similaridade do 1o registro (resposta) com os demais
# =====
# ### Método Cosseno

# %%
from gensim import corpora, models, similarities

from sklearn.metrics.pairwise import cosine_similarity

#Similaridade entre o 1 documento (que é o gabarito) e os demais
c=cosine_similarity(train_data_features[0:1],train_data_features)
print(c)
#Imprimir
#for i in range(1,16):
#    print(c[0][i])
# Out:
# [[1.         0.         0.07455478 0.25147277 0.18194353 0.39304295
#   0.5342046  0.79191791 0.0952597  0.73975897 0.72415576 0.67752697
#   0.0906888  0.03390318 0.65329111 0.23529553]]

# %% [markdown]
# ### Método Distância Euclideana

# %%
from sklearn.metrics.pairwise import euclidean_distances

e=euclidean_distances(train_data_features[0:1],train_data_features)

#imprimir
for i in range(1,16):
    print(e[0][i])
# Out:
# 21.118712081942874
# 23.08679276123039
# 20.904544960366874
# 21.283796653792763
# 19.28730152198591
# 17.635192088548397
# 12.767145334803704
# 21.494185260204677
# 14.142135623730951
# 14.38749456993816
# 15.362291495737216
# 23.40939982143925
# 21.42428528562855
# 16.55294535724685
# 20.37154878746336

# %% [markdown]
# ### Método Linear Kernel

# %%
from sklearn.metrics.pairwise import linear_kernel

linear_kernel(train_data_features[0:1],train_data_features)
# Out:
# array([[435.,   0.,  18.,  56.,  36.,  84., 120., 258.,  15., 265., 223.,
#         188.,  24.,   4., 118.,  34.]])
